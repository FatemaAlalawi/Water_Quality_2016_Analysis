# %%
import pandas as pd

# %% [markdown]
# # Data Cleaning

# %%
wq=pd.read_csv('1_gecco2018_water_quality.csv')

# %%
wq
# Out:
#         Unnamed: 0                 Time    Tp    Cl    pH  Redox   Leit  \
# 0                1  2016-08-03 11:49:00   6.5  0.17  8.36  749.0  211.0
# 1                2  2016-08-03 11:50:00   6.5  0.17  8.36  749.0  211.0
# 2                3  2016-08-03 11:51:00   6.5  0.17  8.35  749.0  211.0
# 3                4  2016-08-03 11:52:00   6.5  0.17  8.35  749.0  211.0
# 4                5  2016-08-03 11:53:00   6.5  0.17  8.35  749.0  211.0
# ...            ...                  ...   ...   ...   ...    ...    ...
# 139561      139562  2016-11-08 08:50:00  10.1  0.16  8.41  762.0  189.0
# 139562      139563  2016-11-08 08:51:00  10.1  0.17  8.41  762.0  190.0
# 139563      139564  2016-11-08 08:52:00  10.1  0.17  8.41  762.0  190.0
# 139564      139565  2016-11-08 08:53:00  10.1  0.17  8.41  762.0  190.0
# 139565      139566  2016-11-08 08:54:00  10.1  0.17  8.41  762.0  189.0
#
#         Trueb   Cl_2      Fm   Fm_2  EVENT
# 0       0.011  0.118  1677.0  695.0  False
# ...

# %%
wq.columns
# Out:
# Index(['Unnamed: 0', 'Time', 'Tp', 'Cl', 'pH', 'Redox', 'Leit', 'Trueb',
#        'Cl_2', 'Fm', 'Fm_2', 'EVENT'],
#       dtype='object')

# %%
wq.pop('Unnamed: 0')
# Out:
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5
#            ...
# 139561    139562
# 139562    139563
# 139563    139564
# 139564    139565
# 139565    139566
# Name: Unnamed: 0, Length: 139566, dtype: int64

# %%
wq
# Out:
#                        Time    Tp    Cl    pH  Redox   Leit  Trueb   Cl_2  \
# 0       2016-08-03 11:49:00   6.5  0.17  8.36  749.0  211.0  0.011  0.118
# 1       2016-08-03 11:50:00   6.5  0.17  8.36  749.0  211.0  0.011  0.118
# 2       2016-08-03 11:51:00   6.5  0.17  8.35  749.0  211.0  0.011  0.117
# 3       2016-08-03 11:52:00   6.5  0.17  8.35  749.0  211.0  0.011  0.118
# 4       2016-08-03 11:53:00   6.5  0.17  8.35  749.0  211.0  0.011  0.118
# ...                     ...   ...   ...   ...    ...    ...    ...    ...
# 139561  2016-11-08 08:50:00  10.1  0.16  8.41  762.0  189.0  0.023  0.105
# 139562  2016-11-08 08:51:00  10.1  0.17  8.41  762.0  190.0  0.022  0.106
# 139563  2016-11-08 08:52:00  10.1  0.17  8.41  762.0  190.0  0.022  0.106
# 139564  2016-11-08 08:53:00  10.1  0.17  8.41  762.0  190.0  0.022  0.106
# 139565  2016-11-08 08:54:00  10.1  0.17  8.41  762.0  189.0  0.022  0.106
#
#             Fm   Fm_2  EVENT
# 0       1677.0  695.0  False
# ...

# %%
wq['Time']
# Out:
# 0         2016-08-03 11:49:00
# 1         2016-08-03 11:50:00
# 2         2016-08-03 11:51:00
# 3         2016-08-03 11:52:00
# 4         2016-08-03 11:53:00
#                  ...
# 139561    2016-11-08 08:50:00
# 139562    2016-11-08 08:51:00
# 139563    2016-11-08 08:52:00
# 139564    2016-11-08 08:53:00
# 139565    2016-11-08 08:54:00
# Name: Time, Length: 139566, dtype: object

# %%
wq['Time']=pd.to_datetime(wq['Time'], format='%Y-%m-%d %H:%M:%S')

# %%
wq
# Out:
#                       Time    Tp    Cl    pH  Redox   Leit  Trueb   Cl_2  \
# 0      2016-08-03 11:49:00   6.5  0.17  8.36  749.0  211.0  0.011  0.118
# 1      2016-08-03 11:50:00   6.5  0.17  8.36  749.0  211.0  0.011  0.118
# 2      2016-08-03 11:51:00   6.5  0.17  8.35  749.0  211.0  0.011  0.117
# 3      2016-08-03 11:52:00   6.5  0.17  8.35  749.0  211.0  0.011  0.118
# 4      2016-08-03 11:53:00   6.5  0.17  8.35  749.0  211.0  0.011  0.118
# ...                    ...   ...   ...   ...    ...    ...    ...    ...
# 139561 2016-11-08 08:50:00  10.1  0.16  8.41  762.0  189.0  0.023  0.105
# 139562 2016-11-08 08:51:00  10.1  0.17  8.41  762.0  190.0  0.022  0.106
# 139563 2016-11-08 08:52:00  10.1  0.17  8.41  762.0  190.0  0.022  0.106
# 139564 2016-11-08 08:53:00  10.1  0.17  8.41  762.0  190.0  0.022  0.106
# 139565 2016-11-08 08:54:00  10.1  0.17  8.41  762.0  189.0  0.022  0.106
#
#             Fm   Fm_2  EVENT
# 0       1677.0  695.0  False
# 1       1561.0  696.0  False
# ...

# %%
wq['Time']
# Out:
# 0        2016-08-03 11:49:00
# 1        2016-08-03 11:50:00
# 2        2016-08-03 11:51:00
# 3        2016-08-03 11:52:00
# 4        2016-08-03 11:53:00
#                  ...
# 139561   2016-11-08 08:50:00
# 139562   2016-11-08 08:51:00
# 139563   2016-11-08 08:52:00
# 139564   2016-11-08 08:53:00
# 139565   2016-11-08 08:54:00
# Name: Time, Length: 139566, dtype: datetime64[ns]

# %%
wq['Date']=wq['Time'].dt.date
#wq['Time']=wq['Time'].dt.time

# %%
wq
# Out:
#                       Time    Tp    Cl    pH  Redox   Leit  Trueb   Cl_2  \
# 0      2016-08-03 11:49:00   6.5  0.17  8.36  749.0  211.0  0.011  0.118
# 1      2016-08-03 11:50:00   6.5  0.17  8.36  749.0  211.0  0.011  0.118
# 2      2016-08-03 11:51:00   6.5  0.17  8.35  749.0  211.0  0.011  0.117
# 3      2016-08-03 11:52:00   6.5  0.17  8.35  749.0  211.0  0.011  0.118
# 4      2016-08-03 11:53:00   6.5  0.17  8.35  749.0  211.0  0.011  0.118
# ...                    ...   ...   ...   ...    ...    ...    ...    ...
# 139561 2016-11-08 08:50:00  10.1  0.16  8.41  762.0  189.0  0.023  0.105
# 139562 2016-11-08 08:51:00  10.1  0.17  8.41  762.0  190.0  0.022  0.106
# 139563 2016-11-08 08:52:00  10.1  0.17  8.41  762.0  190.0  0.022  0.106
# 139564 2016-11-08 08:53:00  10.1  0.17  8.41  762.0  190.0  0.022  0.106
# 139565 2016-11-08 08:54:00  10.1  0.17  8.41  762.0  189.0  0.022  0.106
#
#             Fm   Fm_2  EVENT        Date
# 0       1677.0  695.0  False  2016-08-03
# ...

# %%
wq['time']=wq['Time'].dt.time

# %%
wq.pop('Time')
# Out:
# 0        2016-08-03 11:49:00
# 1        2016-08-03 11:50:00
# 2        2016-08-03 11:51:00
# 3        2016-08-03 11:52:00
# 4        2016-08-03 11:53:00
#                  ...
# 139561   2016-11-08 08:50:00
# 139562   2016-11-08 08:51:00
# 139563   2016-11-08 08:52:00
# 139564   2016-11-08 08:53:00
# 139565   2016-11-08 08:54:00
# Name: Time, Length: 139566, dtype: datetime64[ns]

# %%
wq
# Out:
#           Tp    Cl    pH  Redox   Leit  Trueb   Cl_2      Fm   Fm_2  EVENT  \
# 0        6.5  0.17  8.36  749.0  211.0  0.011  0.118  1677.0  695.0  False
# 1        6.5  0.17  8.36  749.0  211.0  0.011  0.118  1561.0  696.0  False
# 2        6.5  0.17  8.35  749.0  211.0  0.011  0.117  1581.0  696.0  False
# 3        6.5  0.17  8.35  749.0  211.0  0.011  0.118  1579.0  693.0  False
# 4        6.5  0.17  8.35  749.0  211.0  0.011  0.118  1567.0  689.0  False
# ...      ...   ...   ...    ...    ...    ...    ...     ...    ...    ...
# 139561  10.1  0.16  8.41  762.0  189.0  0.023  0.105  1799.0  924.0  False
# 139562  10.1  0.17  8.41  762.0  190.0  0.022  0.106  1835.0  927.0  False
# 139563  10.1  0.17  8.41  762.0  190.0  0.022  0.106  1807.0  924.0  False
# 139564  10.1  0.17  8.41  762.0  190.0  0.022  0.106  1799.0  930.0  False
# 139565  10.1  0.17  8.41  762.0  189.0  0.022  0.106  1817.0  925.0  False
#
#               Date      time
# 0       2016-08-03  11:49:00
# ...

# %%
wq.dtypes
# Out:
# Tp       float64
# Cl       float64
# pH       float64
# Redox    float64
# Leit     float64
# Trueb    float64
# Cl_2     float64
# Fm       float64
# Fm_2     float64
# EVENT       bool
# Date      object
# time      object
# dtype: object

# %%
wq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139566 entries, 0 to 139565
# Data columns (total 12 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Tp      138522 non-null  float64
#  1   Cl      138521 non-null  float64
#  2   pH      138522 non-null  float64
#  3   Redox   138522 non-null  float64
#  4   Leit    138522 non-null  float64
#  5   Trueb   138522 non-null  float64
#  6   Cl_2    138522 non-null  float64
#  7   Fm      138522 non-null  float64
#  8   Fm_2    138522 non-null  float64
#  9   EVENT   139566 non-null  bool
#  10  Date    139566 non-null  object
#  11  time    139566 non-null  object
# dtypes: bool(1), float64(9), object(2)
# memory usage: 11.8+ MB

# %%
wq.isnull()
# Out:
#            Tp     Cl     pH  Redox   Leit  Trueb   Cl_2     Fm   Fm_2  EVENT  \
# 0       False  False  False  False  False  False  False  False  False  False
# 1       False  False  False  False  False  False  False  False  False  False
# 2       False  False  False  False  False  False  False  False  False  False
# 3       False  False  False  False  False  False  False  False  False  False
# 4       False  False  False  False  False  False  False  False  False  False
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 139561  False  False  False  False  False  False  False  False  False  False
# 139562  False  False  False  False  False  False  False  False  False  False
# 139563  False  False  False  False  False  False  False  False  False  False
# 139564  False  False  False  False  False  False  False  False  False  False
# 139565  False  False  False  False  False  False  False  False  False  False
#
#          Date   time
# 0       False  False
# ...

# %%
wq.isnull().sum()
# Out:
# Tp       1044
# Cl       1045
# pH       1044
# Redox    1044
# Leit     1044
# Trueb    1044
# Cl_2     1044
# Fm       1044
# Fm_2     1044
# EVENT       0
# Date        0
# time        0
# dtype: int64

# %%
wq.isnull().sum()
# Out:
# Tp       1044
# Cl       1045
# pH       1044
# Redox    1044
# Leit     1044
# Trueb    1044
# Cl_2     1044
# Fm       1044
# Fm_2     1044
# EVENT       0
# Date        0
# time        0
# dtype: int64

# %%
wq=wq[['Tp','Cl','pH','Redox','Leit','Trueb','Cl_2','Fm','Fm_2','EVENT','Date','time']].ffill()

# %%
wq.isna().sum()
# Out:
# Tp       0
# Cl       0
# pH       0
# Redox    0
# Leit     0
# Trueb    0
# Cl_2     0
# Fm       0
# Fm_2     0
# EVENT    0
# Date     0
# time     0
# dtype: int64

# %%
wq
# Out:
#           Tp    Cl    pH  Redox   Leit  Trueb   Cl_2      Fm   Fm_2  EVENT  \
# 0        6.5  0.17  8.36  749.0  211.0  0.011  0.118  1677.0  695.0  False
# 1        6.5  0.17  8.36  749.0  211.0  0.011  0.118  1561.0  696.0  False
# 2        6.5  0.17  8.35  749.0  211.0  0.011  0.117  1581.0  696.0  False
# 3        6.5  0.17  8.35  749.0  211.0  0.011  0.118  1579.0  693.0  False
# 4        6.5  0.17  8.35  749.0  211.0  0.011  0.118  1567.0  689.0  False
# ...      ...   ...   ...    ...    ...    ...    ...     ...    ...    ...
# 139561  10.1  0.16  8.41  762.0  189.0  0.023  0.105  1799.0  924.0  False
# 139562  10.1  0.17  8.41  762.0  190.0  0.022  0.106  1835.0  927.0  False
# 139563  10.1  0.17  8.41  762.0  190.0  0.022  0.106  1807.0  924.0  False
# 139564  10.1  0.17  8.41  762.0  190.0  0.022  0.106  1799.0  930.0  False
# 139565  10.1  0.17  8.41  762.0  189.0  0.022  0.106  1817.0  925.0  False
#
#               Date      time
# 0       2016-08-03  11:49:00
# ...

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Part (2): Changes in Parameters that Affect Water Quality Over Time

# %% [markdown]
# #### 1. Safety Standards for Water Quality

# %% [markdown]
# - **pH**: 6.5 – 8.5
# - **Temperature**: < 25°C
# - **Turbidity**: < 5 NTU (ideally < 1 NTU)
# - **Chlorine**: 0.2 – 0.5 mg/L
# - **Redox**: > 650 mV (indicates disinfected water)
# - **Conductivity**: < 500 µS/cm (0.0005 S/cm)
#
#  *Source:* WHO

# %% [markdown]
# #### 2. Convert data per seconds to per day

# %%
daily_Tp_values=wq.groupby(wq['Date'])['Tp'].mean()
daily_pH_values=wq.groupby(wq['Date'])['pH'].mean()
daily_Cl_values=wq.groupby(wq['Date'])['Cl'].mean()
daily_Cl_2_values=wq.groupby(wq['Date'])['Cl_2'].mean()
daily_Redox_values=wq.groupby(wq['Date'])['Redox'].mean()
daily_Leit_values=wq.groupby(wq['Date'])['Leit'].mean()
daily_Trueb_values=wq.groupby(wq['Date'])['Trueb'].mean()
daily_Fm_values=wq.groupby(wq['Date'])['Fm'].mean()
daily_Fm_2_values=wq.groupby(wq['Date'])['Fm_2'].mean()

# %%
Daily_values=pd.DataFrame({'Tp':daily_Tp_values,'pH':daily_pH_values,'Cl':daily_Cl_values,'Cl_2':daily_Cl_2_values,'Redox':daily_Redox_values,'Leit':daily_Leit_values,'Trueb':daily_Trueb_values,'Fm':daily_Fm_values,'Fm_2':daily_Fm_2_values})

# %%
dv=Daily_values

# %%
dv=dv.reset_index()

# %%
dv
# Out:
#           Date         Tp        pH        Cl      Cl_2       Redox  \
# 0   2016-08-03   6.527907  8.339289  0.165718  0.111014  747.923393
# 1   2016-08-04   6.548333  8.355083  0.165694  0.109265  749.259722
# 2   2016-08-05   6.575556  8.356563  0.165042  0.108441  749.548611
# 3   2016-08-06   6.620903  8.366944  0.165938  0.108325  749.459722
# 4   2016-08-07   6.715069  8.355292  0.165500  0.109585  750.452083
# ..         ...        ...       ...       ...       ...         ...
# 93  2016-11-04  10.706458  8.417674  0.167590  0.107438  755.582639
# 94  2016-11-05  10.665764  8.403590  0.163174  0.106377  758.744444
# 95  2016-11-06  10.448681  8.406576  0.164188  0.106653  759.290278
# 96  2016-11-07  10.272847  8.398618  0.164389  0.105827  760.078472
# 97  2016-11-08  10.100748  8.410374  0.162860  0.104114  759.413084
#
#           Leit     Trueb           Fm        Fm_2
# 0   209.864569  0.014130  1475.636115  754.625171
# ...

# %% [markdown]
# #### 3. Visualization of the change of parameters over time

# %%
dv.set_index('Date', inplace=True)

# %%
dv.plot(subplots=True, figsize=(10, 12))
plt.show()

# %% [markdown]
# **Graphs Explanation:**
#
# 1. **Tp:** Temperature is controlled by the company
# 2. **pH:** The pH graph indicates a stable range of 7.0-8.0, with minor fluctuations due to being affected by temperature. It is safe to drink within the safe range, with no scaling risk.
# 3. **Cl:** The graph shows that residual chlorine, in the range of 0.10 to 0.40 mg/L, is safe to drink. The sudden drops are due to raise in the flow rate.
# 4. **Redox:** The graph shows a high redox potential, indicating that the product is safe to drink. It depends on its location if its near the sensor of the first chlore or the second one but it appears that  its affected by the second one, when drops it also drops.
# 5. **Leit:** The graph displays stable conductivity with occasional small peaks due to external factors, suggesting no pollution, and indicates that it is safe to drink.
# 6. **Trueb:** The graph shows mostly low turbidity (<1 NTU) with occasional spikes due to drops in chlore, indicating good filtration and safe drinking.
# 7. **Fm:** Flow rate of the water is controlled by the company.

# %% [markdown]
# #### 4. Result of Change

# %% [markdown]
# All changes of parameters in the three months are within the safety standards for a drinking water

# %%
pH_m=dv['pH'].mean() 
cl_m=dv['Cl'].mean()
redox_m=dv['Redox'].mean() 
leit_m=dv['Leit'].mean() 
trueb_m=dv['Trueb'].mean() 
cl2_m=dv['Cl_2'].mean()

# %%
cl_md=dv['Cl'].median()
cl2_md=dv['Cl_2'].median()
pH_md=dv['pH'].median()
redox_md=dv['Redox'].median()
trueb_md=dv['Trueb'].median()
leit_md=dv['Leit'].median()

# %%
mean_data={'Cl':[cl_m,cl_md],'Cl_2':[cl2_m,cl2_md],'pH':[pH_m,pH_md],'Redox':[redox_m,redox_md],'Leit':[leit_m,leit_md],'Trueb':[trueb_m,trueb_md]}

# %%
md=pd.DataFrame(mean_data)

# %%
Mean_Median_Data_event=md.rename(index={0:'Mean',1:'Median'})
Mean_Median_Data_event
# Out:
#               Cl      Cl_2        pH       Redox        Leit     Trueb
# Mean    0.165426  0.106144  8.366451  752.923567  209.421074  0.019760
# Median  0.165701  0.105952  8.362462  753.259375  210.671181  0.018622
